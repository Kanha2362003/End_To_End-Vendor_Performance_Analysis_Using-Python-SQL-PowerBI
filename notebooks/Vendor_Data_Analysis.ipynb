# %%
import pandas as pd
import os
from sqlalchemy import create_engine
import logging
import time

# ✅ Ensure logs folder exists
os.makedirs('logs', exist_ok=True)

logging.basicConfig(
    filename=r"logs/ingestion_db.log",
    level=logging.DEBUG,
    format="%(asctime)s - %(levelname)s - %(message)s",
    filemode="a"
)

# ✅ Create DB engine
engine = create_engine('sqlite:///inventory.db')  # 3 slashes → relative to script path

def load_raw_data():
    '''This function loads CSVs as dataframes in chunks and ingests them into DB.'''
    start = time.time()
    data = r'C:\Users\kanha\Vendor Analysis\data'  # Update this if needed

    for file in os.listdir(data):
        if file.endswith('.csv'):
            full_path = os.path.join(data, file)
            chunksize = 100000  # Adjust based on memory

            table_name = file[:-4]  # remove .csv extension
            is_first_chunk = True

            for chunk in pd.read_csv(full_path, chunksize=chunksize):
                logging.info(f'Ingesting chunk from {file} into table {table_name}')
                
                if_exists_option = 'replace' if is_first_chunk else 'append'
                try:
                    chunk.to_sql(table_name, con=engine, if_exists=if_exists_option, index=False)
                    logging.info(f'Successfully ingested chunk into {table_name} (mode={if_exists_option})')
                except Exception as e:
                    logging.error(f'Error ingesting chunk from {file}: {e}')
                is_first_chunk = False

    end = time.time()
    total_time = (end - start) / 60
    logging.info('----- Ingestion Complete ------')
    logging.info(f'Total Time Taken: {total_time:.2f} minutes')

if __name__ == '__main__':
    load_raw_data()

# %%
engine= create_engine('sqlite:////inventory.db')

def ingest_db(df, table_name, engine):
    '''This function will ingest the dataframe into database table'''
    df.to_sql(table_name, con = engine, if_exists='replace', index = False)


def load_raw_data():
    '''this function will load the CSVs as dataframe and ingest into db'''
    start= time.time()
    for file in os.listdir(data):
      if file.endswith('.csv'):
        full_path = os.path.join(data, file)
        chunksize = 100000  # adjust to your memory

        for chunk in pd.read_csv(full_path, chunksize=chunksize):
            logging.info(f'Ingesting {file} in db')
            ingest_db(chunk, file[:-4], engine)
    end=time.time()
    total_time =(end-start)/60 
    logging.info('-----Ingestion Complete------')       

    logging.info(f'\nTotal Time Taken:{total_time} minutes')

# %%
for file in os.listdir('C:\\Users\\kanha\\Vendor Analysis\\data'):
    print(file)
# Out:
# .ipynb_checkpoints
# begin_inventory.csv
# end_inventory.csv
# purchases.csv
# purchase_prices.csv
# sales.csv
# Vendor_Data_Analysis.ipynb
# vendor_invoice.csv

# %%
data = r'C:\\Users\\kanha\\Vendor Analysis\\data'

# %%
def ingest_db(df, table_name, engine):
    '''This function will ingest the dataframe into database table'''
    df.to_sql(table_name, con = engine, if_exists='replace', index = False)


def load_raw_data():
    '''this function will load the CSVs as dataframe and ingest into db'''
    start= time.time()
    for file in os.listdir(data):
    if file.endswith('.csv'):
        full_path = os.path.join(data, file)
        chunksize = 100000  # adjust to your memory

        for chunk in pd.read_csv(full_path, chunksize=chunksize):
            logging.info(f'Ingesting {file} in db')
            ingest_db(chunk, file[:-4], engine)
    end=time.time()
    total_time =(end-start)/60 
    logging.info('-----Ingestion Complete------')       

    logging.info(f'\nTotal Time Taken:{total_time} minutes')
# Out:
# (100000, 9)
# (100000, 9)
# (6529, 9)
# (100000, 9)
# (100000, 9)
# (24489, 9)
# (100000, 16)
# (100000, 16)
# (100000, 16)
# (100000, 16)
# (100000, 16)
# (100000, 16)
# (100000, 16)
# (100000, 16)
# (100000, 16)
# (100000, 16)
# (100000, 16)
# (100000, 16)
# (100000, 16)
# (100000, 16)
# (100000, 16)
# (100000, 16)
# (100000, 16)
# (100000, 16)
# (100000, 16)
# (100000, 16)
# (100000, 16)
# (100000, 16)
# (100000, 16)
# (72474, 16)
# (12261, 9)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# (100000, 14)
# ...

# %%
def ingest_db(df, table_name, engine):
    '''This function will ingest the dataframe into database table'''
    df.to_sql(table_name, con = engine, if_exists='replace', index = False)

# %%
db_folder = r'C:\Users\kanha\Vendor Analysis\data'
os.makedirs(db_folder, exist_ok=True)  

db_path = os.path.join(db_folder, 'inventory.db')

engine = create_engine(f'sqlite:///{db_path}')
